# %% [markdown]
# # Form2SDCTemplate: Convert Forms to SDC4 Templates
#
# **Version 4.5.0** | [PyPI](https://pypi.org/project/form2sdc/) | [GitHub](https://github.com/SemanticDataCharter/Form2SDCTemplate)
#
# This notebook converts PDF, DOCX, and image forms into SDC4-compliant markdown templates using Google Gemini.
#
# **How it works:**
# 1. Upload your form (PDF, DOCX, PNG, JPG)
# 2. Gemini analyzes the form structure and extracts fields
# 3. (Optional) SDCStudio catalog is searched for reusable components
# 4. A validated SDC4 markdown template is generated with reuse references
# 5. Download the template for use with SDCStudio
#
# > ⚠️ **Note:** If you see a `503 Service Unavailable` error, the Gemini model is temporarily overloaded. Wait a minute and re-run the cell.
#
# [![Open in Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/SemanticDataCharter/Form2SDCTemplate/blob/main/notebooks/form_to_template.ipynb)

# %%
# Cell 1: Setup - Install dependencies
import subprocess
import sys

subprocess.check_call(
    [sys.executable, "-m", "pip", "install", "-q", "--upgrade",
     "form2sdc"]
)

# Clear any cached modules so the latest version is loaded
for mod_name in list(sys.modules):
    if mod_name.startswith("form2sdc"):
        del sys.modules[mod_name]

import form2sdc
print(f"form2sdc {form2sdc.__version__} installed successfully!")

# %% [markdown]
# ## API Key Setup
#
# This notebook uses **Google Gemini** to analyze your forms. You need a free API key:
#
# 1. Go to [Google AI Studio](https://aistudio.google.com/apikey)
# 2. Click **Create API Key** (sign in with any Google account)
# 3. Copy the key — you'll paste it in the next cell when prompted
#
# The free tier is sufficient for form conversion. Your key is entered via a masked input field and is not stored.

# %% [markdown]
# ## SDCStudio Component Reuse
#
# This notebook checks the public [SDCStudio](https://sdcstudio.axius-sdc.com) **component catalog** for
# definitions that already exist, and reuses them instead of defining the same field again.
# There are currently over 6,700 published, public components.
#
# **This works for everyone. No account, no API key, no charge.** The catalog endpoint is public.
#
# Reuse is the point of the exercise: a component is authored once, by someone who knows what it
# means, and every later model assembles it rather than paying for it again.
#
# **An SDCStudio API key is optional** and does exactly one thing: raises your rate limit from
# 200 to 2,000 catalog requests per hour. You only need it for very large forms or repeated runs.
# To get one: log in, then profile icon (top-right) > **Settings** > **API Keys** > **Generate API Key**.

# %%
# Cell 2: Configuration
import getpass
import os

# Google AI API key (required)
if "GOOGLE_API_KEY" in os.environ:
    api_key = os.environ["GOOGLE_API_KEY"]
    print("Using GOOGLE_API_KEY from environment.")
else:
    api_key = getpass.getpass("Enter your Google AI API key: ")
    print("Google AI API key set.")

# SDCStudio API key (optional, raises the catalog rate limit only)
#
# Component reuse does NOT depend on this. The catalog endpoint is public, and
# its URL lives in form2sdc.catalog. A key lifts the limit from 200 to 2,000
# requests per hour, which matters only for very large forms or repeated runs.
sdcstudio_key = None

if "SDCSTUDIO_API_KEY" in os.environ:
    sdcstudio_key = os.environ["SDCSTUDIO_API_KEY"]
    print("Using SDCSTUDIO_API_KEY from environment: higher catalog rate limit.")
else:
    sdcstudio_key = getpass.getpass(
        "SDCStudio API key for a higher rate limit (press Enter to skip): "
    )
    if sdcstudio_key:
        print("SDCStudio API key set: higher catalog rate limit.")
    else:
        sdcstudio_key = None
        print("No SDCStudio key. Component reuse still runs, at the public rate limit.")

# Model selection
model = "gemini-3-flash-preview"
print(f"\nModel: {model}")

# %%
# Cell 3: Upload your form
uploaded_file = None
uploaded_filename = None

try:
    # Google Colab file upload
    from google.colab import files as colab_files
    uploaded = colab_files.upload()
    if uploaded:
        uploaded_filename = list(uploaded.keys())[0]
        uploaded_file = uploaded[uploaded_filename]
        print(f"Uploaded: {uploaded_filename} ({len(uploaded_file):,} bytes)")
except ImportError:
    # Jupyter fallback - use file path
    from pathlib import Path
    file_path_str = input("Enter the path to your form file: ").strip()
    if file_path_str:
        p = Path(file_path_str)
        if p.exists():
            uploaded_filename = p.name
            uploaded_file = p.read_bytes()
            print(f"Loaded: {uploaded_filename} ({len(uploaded_file):,} bytes)")
        else:
            print(f"File not found: {file_path_str}")

if uploaded_file is None:
    print("No file uploaded. Please run this cell again.")

# %%
# Cell 4: Analyze the form (extract fields and structure)
from pathlib import Path
from form2sdc.analyzer import GeminiAnalyzer

if uploaded_file is None:
    print("Please upload a file in Cell 3 first.")
else:
    print(f"Analyzing {uploaded_filename}...")

    analyzer = GeminiAnalyzer(api_key=api_key, model=model)
    analysis = analyzer.analyze(
        file_path=Path(uploaded_filename),
        file_content=uploaded_file,
    )

    # Show what Gemini extracted
    print(f"\nDataset: {analysis.dataset_name}")
    if analysis.domain:
        print(f"Domain: {analysis.domain}")

    # Collect all field names from the Data section
    all_columns = list(analysis.data.columns)

    print(f"Data section: {analysis.data.name}")
    print(f"Fields: {len(all_columns)}")

    if analysis.subject:
        print(f"Subject: {analysis.subject.name}")
    if analysis.provider:
        print(f"Provider: {analysis.provider.name}")
    if analysis.participations:
        for p in analysis.participations:
            print(f"Participation: {p.name}")
    if analysis.workflow:
        print(f"Workflow: {analysis.workflow.name}")

    print("\nExtracted fields:")
    for col in all_columns:
        print(f"  - {col.name} ({col.column_type.value})")

    print("\nAnalysis complete!")

# %% [markdown]
# ### Troubleshooting
#
# | Error | Cause | Fix |
# |-------|-------|-----|
# | **503 Service Unavailable** | Gemini model is temporarily overloaded | Wait 1-2 minutes, then re-run the cell |
# | **TimeoutError** | Large request (especially with catalog reuse) took too long | Re-run the cell; if persistent, try a smaller form or skip catalog reuse |
# | **400 Bad Request** | Invalid API key or unsupported file type | Check your API key; ensure the file is PDF, DOCX, PNG, or JPG |
#
# These errors can occur in any cell that calls the Gemini API (Cells 4 and 6).
#
# > 🛑 **Do NOT refresh the browser tab!** Refreshing destroys your entire runtime — you will lose your API keys, uploaded file, and all progress. Instead, just **wait 1-2 minutes and re-run the failed cell**. Your data is preserved between cell runs.

# %%
# Cell 5: Match form fields against the public SDCStudio catalog
#
# Runs for everyone. The catalog endpoint needs no authentication; a key only
# raises the rate limit. Matching is deterministic and type-checked: a match is
# accepted only when the catalog component's type equals the type inferred for
# the column, because md2pd rejects a ReuseComponent pointing at the wrong type.
from form2sdc.catalog import apply_catalog_reuse

reuse_report = None

if 'analysis' not in dir():
    print("Run Cell 4 first to analyze the form.")
else:
    print("Matching fields against the SDCStudio component catalog...\n")

    # Sets reuse_component on every column that has a type-correct match, so
    # the template builder emits it directly. No second LLM call is involved.
    reuse_report = apply_catalog_reuse(analysis, api_key=sdcstudio_key)

    print(reuse_report.summary())

    if not reuse_report.available:
        print("\nThe template will still be generated, defining every component fresh.")

# %%
# Cell 6: Build the template
#
# Reuse references were assigned deterministically in Cell 5 and the builder
# emits them verbatim, so there is no second analysis pass here. Re-prompting
# the LLM to honour catalog matches was both an extra call and a chance for it
# to decline; setting the field directly cannot fail that way.
from form2sdc.template_builder import TemplateBuilder
from form2sdc.validator import Form2SDCValidator

if 'analysis' not in dir():
    print("Please run Cell 4 first.")
else:
    builder = TemplateBuilder()
    template = builder.build(analysis)

    validator = Form2SDCValidator()
    validation = validator.validate(template, document=uploaded_filename)

    print("Template built.")
    if reuse_report and reuse_report.matched:
        print(f"Component reuse: {len(reuse_report.matched)} field(s) bound to "
              f"existing catalog components.")
    else:
        print("Component reuse: none applied; every component is defined fresh.")

# %%
# Cell 7: Validation results
if 'validation' not in dir():
    print("Please run Cell 6 first.")
else:
    if validation.valid:
        print("VALIDATION PASSED")
    else:
        print("VALIDATION ISSUES FOUND")

    if validation.errors:
        print(f"\n--- CRITICAL ERRORS ({len(validation.errors)}) ---")
        for e in validation.errors:
            print(f"  [{e.code}] Line {e.line}: {e.message}")
            if e.fix:
                print(f"    Fix: {e.fix}")

    if validation.warnings:
        print(f"\n--- WARNINGS ({len(validation.warnings)}) ---")
        for w in validation.warnings:
            print(f"  [{w.code}] Line {w.line}: {w.message}")

    if validation.suggestions:
        print(f"\n--- SUGGESTIONS ({len(validation.suggestions)}) ---")
        for s in validation.suggestions:
            print(f"  [{s.code}] {s.message}")

    print(f"\nTotal: {len(validation.errors)} errors, {len(validation.warnings)} warnings, {len(validation.suggestions)} suggestions")

# %%
# Cell 8: Preview template as rendered markdown
if 'template' not in dir():
    print("Please run Cell 6 first.")
else:
    try:
        from IPython.display import Markdown, display
        display(Markdown(template))
    except ImportError:
        print(template)

# %%
# Cell 9: Raw markdown (for copying)
if 'template' not in dir():
    print("Please run Cell 6 first.")
else:
    print(template)

# %%
# Cell 10: Download template
if 'template' not in dir():
    print("Please run Cell 6 first.")
else:
    # Generate filename from dataset name
    safe_name = analysis.dataset_name.replace(" ", "_").lower()
    output_filename = f"{safe_name}_template.md"

    # Save to file
    with open(output_filename, "w", encoding="utf-8") as f:
        f.write(template)
    print(f"Saved: {output_filename}")

    # Trigger download in Colab
    try:
        from google.colab import files as colab_files
        colab_files.download(output_filename)
        print("Download started!")
    except ImportError:
        print(f"File saved to: {output_filename}")
